# %%
import requests
from bs4 import BeautifulSoup
import mechanize

# %%
homeUrl = "https://slcm.manipal.edu/loginForm.aspx";
acadsUrl = "https://slcm.manipal.edu/Academics.aspx";
credentials = {
  'txtUserid': ,
  'txtpassword': ""
};
action="./loginForm.aspx"

# %%
page=requests.get(homeUrl)

# %%
soup = BeautifulSoup(page.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    MU SLcM
#   </title>
#   <link href="images/fevicon.png" rel="shortcut icon"/>
#   <link href="assets/plugins/bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
#   <link href="assets/css/common.css" rel="stylesheet"/>
#   <script lang="javascript" type="text/javascript">
#    function DisableBackButton() {
#             window.history.forward()
#         }
#         DisableBackButton();
#         window.onload = DisableBackButton;
#         window.onpageshow = function (evt) { if (evt.persisted) DisableBackButton() }
#         window.onunload = function () { void (0) }
#   </script>
#   <style>
#    .btn-warning-border {
#             border:0;
#             border-radius:0;
#             margin-bottom:10px;
#         }
#   </style>
#  </head>
#  <body class="login_page">
#   <div class="login_header p-10">
#    <a href="https://manipal.edu/" target="_blank">
#     <img src="images/logo.png"/>
#    </a>
#   </div>
#   <div class="carousel slide carousel-fade" data-interval="3000" data-pause="false" data-ride="carousel">
#    <div class="carousel-inner" role="listbox">
#     <div class="item active">
#     </div>
#     <div class="item">
#     </div>
#     <div class="item">
#     </div>
#    </div>
#   </div>
#   <form action="./loginForm.aspx" id="form1" method="post" name="form1">
#    <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="/wEPDwULLTE4NTA1MzM2ODIPZBYCAgMPZBYCAgMPZBYCZg9kFgICAw8PFgIeB1Zpc2libGVoZGRkZQeElbA4UBZ/sIRqcKZDYpcgTP0="/>
#    <script src="Scripts/WebForms/MsAjax/MicrosoftAjax.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     //<![CDATA[
# if (typeof(Sys) === 'undefined') throw new Error('ASP.NET Ajax client-side framework failed to load.');
# //]]>
#    </script>
#    <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="6ED0046F"/>
#    <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="/wEdAAbdzkkY3m2QukSc6Qo1ZHjQdR78oILfrSzgm87C/a1IYZxpWckI3qdmfEJVCu2f5cEJlsYldsTO6iyyyy0NDvcAop4oRunf14dz2Zt2+QKDEIHFert2MhVDDgiZPfTqiMme8dYSy24aMNCGMYN2F8ckIbO3nw=="/>
#    <div id="updpnl">
#     <div id="pnlSignIn">
#      <div class="login_form">
#       <p class="m-0 p-5">
#        Sign in to your account
#       </p>
#       <div class="p-20">
#        <div class="form-group mt-35 mb-20">
#         <input autocomplet="off" class="form-control" id="txtUserid" maxlength="30" name="txtUserid" placeholder="Username" type="text"/>
#        </div>
#        <div class="form-group">
#         <input autocomplet="off" class="form-control" id="txtpassword" maxlength="30" name="txtpassword" placeholder="Password" type="password"/>
#         <a class="forgetpassword mt-5" href="javascript:__doPostBack('hrpConfirmation','')" id="hrpConfirmation">
#          Forgot Password
#         </a>
#         <span id="labelerror">
#          <font color="Red" size="3">
#          </font>
#         </span>
#        </div>
#        <div class="form-group text-c">
#         <span id="lblHRUserId">
#         </span>
#         <input class="btn btn-primary signin" id="btnLogin" name="btnLogin" type="submit" value="Sign in"/>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="modal fade confirm-modal" id="confirmModal" role="dialog">
#     <div class="modal-dialog modal-sm">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button class="close" data-dismiss="modal" type="button">
#         ×
#        </button>
#        <h4 class="modal-title">
#         Confirmation
#        </h4>
#       </div>
#       <div class="modal-body text-center">
#        <p>
#         Are You Sure?
#        </p>
#       </div>
#       <div class="modal-footer">
#        <input class="btn btn-success" data-dismiss="modal" id="hrpForgot" name="hrpForgot" onclick="javascript:__doPostBack('hrpForgot','')" type="button" value="Yes"/>
#        <button class="btn btn-danger" data-dismiss="modal" id="btnNo" type="button">
#         No
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#   </form>
#   <div class="login_footer p-10">
#    ©2017 Manipal Academy of Higher Education, manipal.edu, Madhav Nagar, Manipal-576104, Karnataka.
#   </div>
#   <script src="assets/plugins/jQuery-lib/2.0.3/jquery.min.js">
#   </script>
#   <script src="assets/plugins/bootstrap/js/bootstrap.min.js">
#   </script>
#   <script>
#    $(document).keypress(function (e) {
#
#
#            var x = document.getElementById("confirmModal");
#            if (x.style.display == "block") {
#                if (e.which == 13) {
#                    $('#btnNo').trigger('click');
#                }
#            }
#            else {
#                if (e.which == 13) {
#                    $('#btnLogin').trigger('click');
#                }
#            }
#            //if (e.which == 13) {
#            //    $('#btnLogin').trigger('click');
#            //}
#        });
#   </script>
#  </body>
# </html>

# %%
response=[]
browser=mechanize.Browser()
browser.open(homeUrl)
browser.select_form(name='form1')
browser.form['txtUserid'] = '170907474'
browser.form['txtpassword'] = "Shrimataji@30"
browser.method = "POST"
ress=browser.submit()
xx=browser.open(acadsUrl)
yy=xx.read()
soup = BeautifulSoup(yy, 'html.parser')
#print(soup.prettify())
div = soup.find('div', {'id' : 'accordion'})
sub_names = [sub.text for sub in soup.find_all('a', {'data-parent' : '#accordion'})]
sub_names = [sub.split('\n')[2] for sub in sub_names]
sub_names = [' '.join(s.split(' ')[4:]) for s in sub_names]
sub_names = [s[1:] for s in sub_names]
sub_names = [i.strip() for i in sub_names]
sub_marks = soup.find_all('td',style="border-collapse: collapse; border: 1px solid black; text-align: center")
print(sub_names)

for k,sub in enumerate(sub_marks):
    
    for i in sub:
        response.append(i)
    
    

# for k, sub in enumerate(sub_marks):
#     entries = [i.text for i in sub.find_all('td')]
#     resp = {}
#     for x in range(0, len(entries) - 2, 3):
#         resp[entries[x]] = { "Total" : entries[x+1], "Obtained" : entries[x+2]}
#     response[sub_names[k]] = resp
# print(response)
# Out:
# ['LINEAR AND DIGITAL CONTROL SYSTEMS', 'MICROCONTROLLERS', 'ANALOG COMMUNICATION', 'VLSI DESIGN', 'COMMUNICATION NETWORKS', 'COMPUTER ORGANIZATION AND ARCHITECTURE', 'MICROCONTROLLER LAB', 'VLSI LAB']

# %%
page=requests.get(acadsUrl)
soup = BeautifulSoup(page.text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    MU SLcM
#   </title>
#   <link href="images/fevicon.png" rel="shortcut icon"/>
#   <link href="assets/plugins/bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
#   <link href="assets/css/common.css" rel="stylesheet"/>
#   <script lang="javascript" type="text/javascript">
#    function DisableBackButton() {
#             window.history.forward()
#         }
#         DisableBackButton();
#         window.onload = DisableBackButton;
#         window.onpageshow = function (evt) { if (evt.persisted) DisableBackButton() }
#         window.onunload = function () { void (0) }
#   </script>
#   <style>
#    .btn-warning-border {
#             border:0;
#             border-radius:0;
#             margin-bottom:10px;
#         }
#   </style>
#  </head>
#  <body class="login_page">
#   <div class="login_header p-10">
#    <a href="https://manipal.edu/" target="_blank">
#     <img src="images/logo.png"/>
#    </a>
#   </div>
#   <div class="carousel slide carousel-fade" data-interval="3000" data-pause="false" data-ride="carousel">
#    <div class="carousel-inner" role="listbox">
#     <div class="item active">
#     </div>
#     <div class="item">
#     </div>
#     <div class="item">
#     </div>
#    </div>
#   </div>
#   <form action="./loginForm.aspx" id="form1" method="post" name="form1">
#    <input id="__VIEWSTATE" name="__VIEWSTATE" type="hidden" value="/wEPDwULLTE4NTA1MzM2ODIPZBYCAgMPZBYCAgMPZBYCZg9kFgICAw8PFgIeB1Zpc2libGVoZGRkZQeElbA4UBZ/sIRqcKZDYpcgTP0="/>
#    <script src="Scripts/WebForms/MsAjax/MicrosoftAjax.js" type="text/javascript">
#    </script>
#    <script type="text/javascript">
#     //<![CDATA[
# if (typeof(Sys) === 'undefined') throw new Error('ASP.NET Ajax client-side framework failed to load.');
# //]]>
#    </script>
#    <input id="__VIEWSTATEGENERATOR" name="__VIEWSTATEGENERATOR" type="hidden" value="6ED0046F"/>
#    <input id="__EVENTVALIDATION" name="__EVENTVALIDATION" type="hidden" value="/wEdAAbdzkkY3m2QukSc6Qo1ZHjQdR78oILfrSzgm87C/a1IYZxpWckI3qdmfEJVCu2f5cEJlsYldsTO6iyyyy0NDvcAop4oRunf14dz2Zt2+QKDEIHFert2MhVDDgiZPfTqiMme8dYSy24aMNCGMYN2F8ckIbO3nw=="/>
#    <div id="updpnl">
#     <div id="pnlSignIn">
#      <div class="login_form">
#       <p class="m-0 p-5">
#        Sign in to your account
#       </p>
#       <div class="p-20">
#        <div class="form-group mt-35 mb-20">
#         <input autocomplet="off" class="form-control" id="txtUserid" maxlength="30" name="txtUserid" placeholder="Username" type="text"/>
#        </div>
#        <div class="form-group">
#         <input autocomplet="off" class="form-control" id="txtpassword" maxlength="30" name="txtpassword" placeholder="Password" type="password"/>
#         <a class="forgetpassword mt-5" href="javascript:__doPostBack('hrpConfirmation','')" id="hrpConfirmation">
#          Forgot Password
#         </a>
#         <span id="labelerror">
#          <font color="Red" size="3">
#          </font>
#         </span>
#        </div>
#        <div class="form-group text-c">
#         <span id="lblHRUserId">
#         </span>
#         <input class="btn btn-primary signin" id="btnLogin" name="btnLogin" type="submit" value="Sign in"/>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="modal fade confirm-modal" id="confirmModal" role="dialog">
#     <div class="modal-dialog modal-sm">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button class="close" data-dismiss="modal" type="button">
#         ×
#        </button>
#        <h4 class="modal-title">
#         Confirmation
#        </h4>
#       </div>
#       <div class="modal-body text-center">
#        <p>
#         Are You Sure?
#        </p>
#       </div>
#       <div class="modal-footer">
#        <input class="btn btn-success" data-dismiss="modal" id="hrpForgot" name="hrpForgot" onclick="javascript:__doPostBack('hrpForgot','')" type="button" value="Yes"/>
#        <button class="btn btn-danger" data-dismiss="modal" id="btnNo" type="button">
#         No
#        </button>
#       </div>
#      </div>
#     </div>
#    </div>
#   </form>
#   <div class="login_footer p-10">
#    ©2017 Manipal Academy of Higher Education, manipal.edu, Madhav Nagar, Manipal-576104, Karnataka.
#   </div>
#   <script src="assets/plugins/jQuery-lib/2.0.3/jquery.min.js">
#   </script>
#   <script src="assets/plugins/bootstrap/js/bootstrap.min.js">
#   </script>
#   <script>
#    $(document).keypress(function (e) {
#
#
#            var x = document.getElementById("confirmModal");
#            if (x.style.display == "block") {
#                if (e.which == 13) {
#                    $('#btnNo').trigger('click');
#                }
#            }
#            else {
#                if (e.which == 13) {
#                    $('#btnLogin').trigger('click');
#                }
#            }
#            //if (e.which == 13) {
#            //    $('#btnLogin').trigger('click');
#            //}
#        });
#   </script>
#  </body>
# </html>

# %%
response
# Out:
# ['Internal Sessional 1',
#  '15.00',
#  '13.00',
#  'Total Marks',
#  '15.00',
#  '13.00',
#  '5.00',
#  '4.00',
#  '5.00',
#  '4.00',
#  'Internal Sessional 1',
#  '15.00',
#  '13.00',
#  'Total Marks',
#  '15.00',
#  '13.00',
#  'Internal Sessional 1',
#  '15.00',
#  '13.00',
#  'Total Marks',
#  '15.00',
#  '13.00',
#  'Internal Sessional 1',
#  '15.00',
#  '14.50',
#  'Total Marks',
#  '15.00',
#  '14.50',
#  'Internal Sessional 1',
#  '15.00',
#  '12.50',
#  'Total Marks',
#  '15.00',
#  '12.50',
#  'Internal Sessional 1',
#  '15.00',
#  '13.50',
#  'Total Marks',
#  '15.00',
#  '13.50',
#  '5.00',
#  '5.00',
#  '5.00',
#  '5.00',
#  '10.00',
#  '10.00']
